# %% [markdown]
# https://community.sigames.com/forums/topic/513885-column-headers/

# %% [markdown]
# ## Dulwich Hamlet Squad Assesment

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from IPython.display import display, HTML
import plotly.express as px
import plotly.io as pio
import matplotlib.pyplot as plt
# pio.renderers.default = 'colab'

# %% [markdown]
# ### Helper Function TO display scrollable Dataframe.

# %%
def display_scrollable_dataframe(dataframe):
    # Create an HTML representation of the DataFrame
    html_output = dataframe.to_html()

    # Display the HTML output
    display(HTML(html_output))

# %% [markdown]
# ### Importing the dataset.

# %%
squad_df = pd.read_html('squad_analysis-december-2025.html')[0]

# %%
display_scrollable_dataframe(squad_df.head())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Position Selected</th>
#       <th>Inf</th>
#       <th>Age</th>
#       <th>Name</th>
#       <th>Position</th>
#       <th>Nat</th>
#       <th>Ability</th>
#       <th>Potential</th>
#       <th>Personality</th>
#       <th>Hierarchy</th>
#       <th>Agreed Playing Time</th>
#       <th>Playing Time Happiness</th>
#       <th>Social Groups</th>
#       <th>Morale</th>
#       <th>Overall Happiness</th>
#       <th>Av Rat</th>
#       <th>Apps</th>
#       <th>Mins</th>
#       <th>Det</th>
#       <th>Wor</th>
#       <th>Sta</th>
#       <th>Tea</th>
#       <th>Cnt</th>
#       <th>Acc</th>
#       <th>Vis</th>
#       <th>Thr</th>
#       <th>Tec</th>
#       <th>Tck</th>
#       <th>Str</th>
#       <th>TRO</th>
#       <th>Ref</th>
#       <th>Pun</th>
#       <th>Pos</th>
#       <th>Pen</th>
#       <th>Pas</th>
#       <th>Pac</th>
#       <th>1v1</th>
# ...

# %%
display_scrollable_dataframe(squad_df.sample(5))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Position Selected</th>
#       <th>Inf</th>
#       <th>Age</th>
#       <th>Name</th>
#       <th>Position</th>
#       <th>Nat</th>
#       <th>Ability</th>
#       <th>Potential</th>
#       <th>Personality</th>
#       <th>Hierarchy</th>
#       <th>Agreed Playing Time</th>
#       <th>Playing Time Happiness</th>
#       <th>Social Groups</th>
#       <th>Morale</th>
#       <th>Overall Happiness</th>
#       <th>Av Rat</th>
#       <th>Apps</th>
#       <th>Mins</th>
#       <th>Det</th>
#       <th>Wor</th>
#       <th>Sta</th>
#       <th>Tea</th>
#       <th>Cnt</th>
#       <th>Acc</th>
#       <th>Vis</th>
#       <th>Thr</th>
#       <th>Tec</th>
#       <th>Tck</th>
#       <th>Str</th>
#       <th>TRO</th>
#       <th>Ref</th>
#       <th>Pun</th>
#       <th>Pos</th>
#       <th>Pen</th>
#       <th>Pas</th>
#       <th>Pac</th>
#       <th>1v1</th>
# ...

# %% [markdown]
# ### Column names of the dataset.

# %%
squad_df.columns
# Out:
# Index(['Position Selected', 'Inf', 'Age', 'Name', 'Position', 'Nat', 'Ability',
#        'Potential', 'Personality', 'Hierarchy',
#        ...
#        'Ast', 'AT Lge Gls', 'AT Lge Apps', 'AT Gls', 'Asking Price', 'Wage',
#        'UID', 'No.', 'New Player Trait', 'Dec'],
#       dtype='object', length=195)

# %% [markdown]
# ### Removing NAN Columns

# %%
nan_percentage = (squad_df.isna().sum() / len(squad_df)) * 100
# Create a new DataFrame to display the results
nan_info = pd.DataFrame({
    'Column': squad_df.columns,
    'NaN Percentage': nan_percentage
})

# Sort the DataFrame by NaN Percentage in descending order
nan_info = nan_info.sort_values(by='NaN Percentage', ascending=False)

# %%
cols_to_drop = ['Ability','Injury Risk', 'SHP', 'CON', 'Fatigue', 'Position Selected', "Potential", 'Overall Happiness']

# %%
existing_cols = squad_df.columns.intersection(cols_to_drop)

# %%
squad_df = squad_df.drop(columns=existing_cols)

# %% [markdown]
# ### Data Type of the Dataframe Columns.

# %%
df_data_type = squad_df.dtypes.to_frame(name='Data Type').reset_index().rename(columns={'index': 'Column'})

# %%
display_scrollable_dataframe(df_data_type)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Column</th>
#       <th>Data Type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Inf</td>
#       <td>object</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Age</td>
#       <td>int64</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Name</td>
#       <td>object</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Position</td>
#       <td>object</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Nat</td>
#       <td>object</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Personality</td>
#       <td>object</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Hierarchy</td>
#       <td>object</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Agreed Playing Time</td>
#       <td>object</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Playing Time Happiness</td>
# ...

# %% [markdown]
# ### Cleaning up Number of Appearances.
#
# The Appearances is showed in multiple ways.
# 1. If player has no subtitute appearance then apps are shown as: 30.
# 2. If player has substitute appearance then apps are shown as: 30 (5) -> Where 30 is first team appearance and 5 is the appearance as a substitute.

# %% [markdown]
# - Split the appearance by (5) if it exists. then extract a number from brackets.
# - We can also use regex for more robust cleaning.

# %% [markdown]
# #### Extracting the values using regular expressions.
#
# Extracting the values, splitting them into two parts.
# 1. First Value goes to "Apps".
# 2. Second Value goes to "Substitute_Apps".
# 3. Convert the values from str to numeric.
# 4. if the "Substitute_Apps" have NaN value then convert it to 0.

# %%
squad_df[['Appearances', 'Substitute Appearances']] = squad_df['Apps'].str.extract(r'(\d+)\s*(?:\((\d+|\-)\))?').fillna(0).astype(int)

# %% [markdown]
# ### Cleanup numerical values with units.
#
# Some columns contain values with units in it. for e.g (Km, M, p/w, cm)

# %% [markdown]
# 1. Height - cm
# 2. Distance, Dist/90 - Km

# %%
squad_df['Height'] = squad_df['Height'].str.extract('(\d+)').astype(float)

# %%
squad_df['Distance'] = squad_df['Distance'].str.extract('(\d+)').astype(float)

# %%
squad_df['Dist/90'] = squad_df['Dist/90'].str.extract('(\d+)').astype(float)

# %% [markdown]
# ## Cleaning up Wage data.
#
# The wage data contains special characters. Extract the number from the wage.

# %%
squad_df['Wage'] = squad_df['Wage'].str.extract('(\d+)').astype(float)

# %% [markdown]
# #### To numeric
#
# Converting the columns to numeric values.

# %%
numeric_cols = squad_df.select_dtypes(include='object').apply(pd.to_numeric, errors='coerce').dropna(axis=1, how='all')

# %%
squad_df[numeric_cols.columns] = numeric_cols

# %% [markdown]
# ### Percentage Values
#
# Refactoring the percentage values to numeric. (95% -> 0.95)

# %% [markdown]
# ##### Detect the columns with percentage values as string (95%).

# %%
## Helper function for detecting the columns with percentage values.
def detect_percentage_columns(dataframe):
    percentage_columns = []

    for column in dataframe.columns:
        if dataframe[column].dtype == 'O':  # Check if the column contains object (string) type
            # Use a regular expression to detect percentage values in the form of '90%' or '90 %'
            if dataframe[column].str.match(r'\b\d+\s*%').any():
                percentage_columns.append(column)

    return percentage_columns

# %% [markdown]
# ##### Convert the percentage values.

# %%
def convert_percentage_to_numeric(dataframe):
    for column in dataframe.columns:
        dataframe.loc[:, column] = pd.to_numeric(dataframe[column].str.strip('%'), errors='coerce').fillna(0) / 100

    return dataframe

# %%
percentage_columns = detect_percentage_columns(squad_df)

# %%
squad_df.loc[:, percentage_columns] = convert_percentage_to_numeric(squad_df[percentage_columns])

# %% [markdown]
# ### Handling NAN data
#
# The numerical data contains NaN we will convert the NaN to 0 / 0.0

# %%
nan_percentage = (squad_df.isna().sum() / len(squad_df)) * 100
nan_percentage_series = pd.DataFrame(nan_percentage)
display_scrollable_dataframe(nan_percentage_series)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Inf</th>
#       <td>48.148148</td>
#     </tr>
#     <tr>
#       <th>Age</th>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>Name</th>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>Position</th>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>Nat</th>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>Personality</th>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>Hierarchy</th>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>Agreed Playing Time</th>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>Playing Time Happiness</th>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>Social Groups</th>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <th>Morale</th>
#       <td>0.000000</td>
# ...

# %%
squad_df[squad_df.select_dtypes(include=['float']).columns] = squad_df.select_dtypes(include=['float']).fillna(0.0)
squad_df[squad_df.select_dtypes(include=['int64']).columns] = squad_df.select_dtypes(include=['int64']).fillna(0)
squad_df[squad_df.select_dtypes(include=['object']).columns] = squad_df.select_dtypes(include=['object']).fillna('Unknown')
# Out:
# C:\Users\DELL 5590\AppData\Local\Temp\ipykernel_10904\1764194611.py:3: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   squad_df[squad_df.select_dtypes(include=['object']).columns] = squad_df.select_dtypes(include=['object']).fillna('Unknown')

# %%
squad_df
# Out:
#         Inf  Age                  Name                Position  Nat  \
# 0   Unknown   24           Harry Tyrer                      GK  ENG
# 1   Unknown   22      Harry Birtwistle                D/WB (R)  SIN
# 2   Unknown   26          Harry Ransom        D (C), DM, M (C)  ENG
# 3   Unknown   20        Noah Wadsworth              D (LC), DM  ENG
# 4   Unknown   22           Paulo Aguas           D/WB/M/AM (L)  ENG
# 5       Prm   22           Ben Kershaw        D (C), DM, M (C)  ENG
# 6   Unknown   22            Teddy Rowe                M/AM (C)  ENG
# 7   Unknown   23           Alfie Allen               DM, M (C)  ENG
# 8   Unknown   20        Jack Moorhouse          M (C), AM (RC)  ENG
# 9   Unknown   23    Tarrelle Whittaker         AM (RL), ST (C)  ENG
# 10      Lst   20       Lennon Wheeldon                  ST (C)  ENG
# 11      Unw   20      Lewis Darlington                  ST (C)  ENG
# 12  Unknown   24     David Agbontohoma                   D (C)  ENG
# ...

# %%
nan_percentage = (squad_df.isna().sum() / len(squad_df)) * 100
nan_percentage_series = pd.DataFrame(nan_percentage)
display_scrollable_dataframe(nan_percentage_series)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Inf</th>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>Age</th>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>Name</th>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>Position</th>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>Nat</th>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>Personality</th>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>Hierarchy</th>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>Agreed Playing Time</th>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>Playing Time Happiness</th>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>Social Groups</th>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>Morale</th>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>Av Rat</th>
# ...

# %% [markdown]
# ### Calculating the DNA score of the player.
#
# The main Attributes that are important for the tactic:
# 1. Teamwork
# 2. Anticipation
# 3. Vision
# 4. Decision Making
# 5. Composure
# 6. Passing
# 7. First Touch
# 8. Technique
# 9. Off the ball (attacking Unit)
# 10. Positioning (Defensive Unit)
#
# The secondary attributes (DNA) of our tactics are:
# 1. Work rate
# 2. Concentration

# %%
main_dna_attribs = ['Tea', 'Ant', 'Vis', 'Dec', 'Cmp', 'Pas', 'Fir', 'Tec','OtB', 'Pos']

# %%
def_dna_squad = squad_df[squad_df['Position'].apply(lambda x: ('D ) or ('WB' in x) or ('DM' in x) or ('GK' not in x))]' in x

# %%
other_dna_squad = squad_df[squad_df['Position'].apply(lambda x: (('D ' not in x) and ('D/WB ' not in x)) and ('GK' not in x))][['Name', 'Position']]

# %%
def_dna_attribs = list(filter(lambda x: 'OtB' != x, main_dna_attribs))
att_dna_attribs = list(filter(lambda x: 'Pos' != x, main_dna_attribs))

# %%
(def_dna_squad[def_dna_attribs.pop(-2)] * 5) / 100
# Out:
# 1     0.40
# 2     0.35
# 3     0.40
# 4     0.50
# 5     0.40
# 6     0.60
# 7     0.40
# 8     0.65
# 9     0.30
# 10    0.35
# 11    0.20
# 12    0.30
# 13    0.25
# 14    0.60
# 15    0.50
# 16    0.40
# 17    0.40
# 18    0.45
# 19    0.55
# 20    0.25
# 21    0.35
# 22    0.40
# 23    0.50
# 24    0.40
# 26    0.20
# Name: Pas, dtype: float64

# %%
squad_dna_score = round((squad_df[main_dna_attribs].sum(axis=1) / total_dna_score) * 100, 2)

# %%
squad_df = pd.concat([squad_df, pd.DataFrame({'dna_score': squad_dna_score})], axis=1)

# %%
# Out:
# 0     35.0
# 1     43.5
# 2     45.0
# 3     41.5
# 4     42.5
# 5     47.5
# 6     51.5
# 7     45.5
# 8     38.5
# 9     37.5
# 10    45.0
# 11    36.0
# 12    30.5
# 13    41.0
# 14    55.5
# 15    41.5
# 16    38.0
# 17    38.0
# 18    42.0
# 19    49.0
# 20    31.5
# 21    39.5
# 22    37.5
# 23    44.5
# 24    43.5
# 25    35.5
# 26    36.5
# Name: dna_score, dtype: float64

# %% [markdown]
# ## Exploring the Data

# %% [markdown]
# Squad DNA score vs the Age.

# %%
fig = px.scatter(squad_df, 'Age', 'dna_score', hover_data=['Name', 'Position'], text="Name", width=1200, height=600)
fig.update_traces(textposition='top center', textfont_size=10)
fig.update_layout(
    title_text='Age V/s DNa score',
     
)
fig.add_hline(squad_df['dna_score'].mean(), line_color='red')
fig.add_vline(squad_df['Age'].mean(), line_color='red')
fig.show()

# %%
fig = px.scatter(squad_df, 'Wage', 'dna_score', hover_data=['Name', 'Position'], text="Name", width=1200, height=600)
fig.update_traces(textposition='top center', textfont_size=10)
fig.update_layout(
    title_text='Wage V/s DNa score',
     
)
# px.line(x=squad_df['Wage'].mean(), y=squad_df['dna_score'].mean())
fig.add_hline(squad_df['dna_score'].mean(), line_color='red')
fig.add_vline(squad_df['Wage'].mean(), line_color='red')
fig.show()

# %%
players_by_dna_score_df = squad_df[['Name', 'Position', 'dna_score']].sort_values(by=['dna_score'], ascending=False)

# %%
players_by_dna_score_df.tail(10)
# Out:
#                     Name          Position  dna_score
# 16          Lennon Peake           AM (RL)       38.0
# 17          Matty Carson  D (LC), M/AM (L)       38.0
# 9     Tarrelle Whittaker   AM (RL), ST (C)       37.5
# 22       Jaden Crowhurst             D (R)       37.5
# 26  Noah Aynsley-Johnson            ST (C)       36.5
# 11      Lewis Darlington            ST (C)       36.0
# 25         Nathan Morana                GK       35.5
# 0            Harry Tyrer                GK       35.0
# 20         Lewis Coulton          D/WB (L)       31.5
# 12     David Agbontohoma             D (C)       30.5

# %%
players_by_dna_score_df.head(10)
# Out:
#                 Name                Position  dna_score
# 14        Liam Cross          M (C), AM (LC)       55.5
# 6         Teddy Rowe                M/AM (C)       51.5
# 19      Casey Pettit               DM, M (C)       49.0
# 5        Ben Kershaw        D (C), DM, M (C)       47.5
# 7        Alfie Allen               DM, M (C)       45.5
# 10   Lennon Wheeldon                  ST (C)       45.0
# 2       Harry Ransom        D (C), DM, M (C)       45.0
# 23     Curtis Durose      DM, M (RC), AM (R)       44.5
# 24   Jamie Nicholson  M (L), AM (LC), ST (C)       43.5
# 1   Harry Birtwistle                D/WB (R)       43.5

# %% [markdown]
# ### Calculating the Positional Attributes

# %%
# calculates Goalkeeper_Defend score
squad_df['gkd_key'] = ( squad_df['Agi'] + squad_df['Ref'] )
squad_df['gkd_green'] = ( squad_df['Aer'] + squad_df['Cmd'] + squad_df['Han'] + squad_df['Kic'] + squad_df['Cnt'] + squad_df['Pos'] )
squad_df['gkd_blue'] = ( squad_df['1v1'] + squad_df['Thr'] + squad_df['Ant'] + squad_df['Dec'] )
squad_df['gkd'] =( ( ( squad_df['gkd_key'] * 5) + (squad_df['gkd_green'] * 3) + (squad_df['gkd_blue'] * 1) ) / 32)
squad_df.gkd= squad_df.gkd.round(1)
    


# calculates Sweeper_keeper_Defend score
squad_df['skd_key'] = ( squad_df['Agi'] + squad_df['Ref'] )
squad_df['skd_green'] = ( squad_df['Cmd'] + squad_df['Kic'] + squad_df['1v1'] + squad_df['Ant'] + squad_df['Cnt'] + squad_df['Pos'] )
squad_df['skd_blue'] = ( squad_df['Aer'] + squad_df['Fir'] + squad_df['Han'] + squad_df['Pas'] + squad_df['TRO'] + squad_df['Dec'] + squad_df['Vis'] + squad_df['Acc'] )
squad_df['skd'] =( ( ( squad_df['skd_key'] * 5) + (squad_df['skd_green'] * 3) + (squad_df['skd_blue'] * 1) ) / 36)
squad_df.skd= squad_df.skd.round(1)
    


# calculates Sweeper_keeper_Support score
squad_df['sks_key'] = ( squad_df['Agi'] + squad_df['Ref'] )
squad_df['sks_green'] = ( squad_df['Cmd'] + squad_df['Kic'] + squad_df['1v1'] + squad_df['Ant'] + squad_df['Cnt'] + squad_df['Pos'] )
squad_df['sks_blue'] = ( squad_df['Aer'] + squad_df['Fir'] + squad_df['Han'] + squad_df['Pas'] + squad_df['TRO'] + squad_df['Dec'] + squad_df['Vis'] + squad_df['Acc'] )
squad_df['sks'] =( ( ( squad_df['sks_key'] * 5) + (squad_df['sks_green'] * 3) + (squad_df['sks_blue'] * 1) ) / 36)
squad_df.sks= squad_df.sks.round(1)
    


# calculates Sweeper_keeper_Attack score
squad_df['ska_key'] = ( squad_df['Agi'] + squad_df['Ref'] )
squad_df['ska_green'] = ( squad_df['Cmd'] + squad_df['Kic'] + squad_df['1v1'] + squad_df['Ant'] + squad_df['Cnt'] + squad_df['Pos'] )
squad_df['ska_blue'] = ( squad_df['Aer'] + squad_df['Fir'] + squad_df['Han'] + squad_df['Pas'] + squad_df['TRO'] + squad_df['Dec'] + squad_df['Vis'] + squad_df['Acc'] )
squad_df['ska'] =( ( ( squad_df['ska_key'] * 5) + (squad_df['ska_green'] * 3) + (squad_df['ska_blue'] * 1) ) / 36)
squad_df.ska= squad_df.ska.round(1)
    


# calculates Ball_playing_defender_Defend score
squad_df['bpdd_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Jum'] + squad_df['Cmp'] )
squad_df['bpdd_green'] = ( squad_df['Hea'] + squad_df['Mar'] + squad_df['Pas'] + squad_df['Tck'] + squad_df['Pos'] + squad_df['Str'] )
squad_df['bpdd_blue'] = ( squad_df['Fir'] + squad_df['Tec'] + squad_df['Agg'] + squad_df['Ant'] + squad_df['Bra'] + squad_df['Cnt'] + squad_df['Dec'] + squad_df['Vis'] )
squad_df['bpdd'] =( ( ( squad_df['bpdd_key'] * 5) + (squad_df['bpdd_green'] * 3) + (squad_df['bpdd_blue'] * 1) ) / 46)
squad_df.bpdd= squad_df.bpdd.round(1)
    


# calculates Ball_playing_defender_Stopper score
squad_df['bpds_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Jum'] + squad_df['Cmp'] )
squad_df['bpds_green'] = ( squad_df['Hea'] + squad_df['Pas'] + squad_df['Tck'] + squad_df['Pos'] + squad_df['Str'] + squad_df['Agg'] + squad_df['Bra'] + squad_df['Dec'] )
squad_df['bpds_blue'] = ( squad_df['Fir'] + squad_df['Tec'] + squad_df['Ant'] + squad_df['Cnt'] + squad_df['Vis'] + squad_df['Mar'] )
squad_df['bpds'] =( ( ( squad_df['bpds_key'] * 5) + (squad_df['bpds_green'] * 3) + (squad_df['bpds_blue'] * 1) ) / 50)
squad_df.bpds= squad_df.bpds.round(1)
    


# calculates Ball_playing_defender_Cover score
squad_df['bpdc_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Jum'] + squad_df['Cmp'] )
squad_df['bpdc_green'] = ( squad_df['Mar'] + squad_df['Pas'] + squad_df['Tck'] + squad_df['Pos'] + squad_df['Ant'] + squad_df['Cnt'] + squad_df['Dec'] )
squad_df['bpdc_blue'] = ( squad_df['Fir'] + squad_df['Tec'] + squad_df['Bra'] + squad_df['Vis'] + squad_df['Str'] + squad_df['Hea'] )
squad_df['bpdc'] =( ( ( squad_df['bpdc_key'] * 5) + (squad_df['bpdc_green'] * 3) + (squad_df['bpdc_blue'] * 1) ) / 47)
squad_df.bpdc= squad_df.bpdc.round(1)
    


# calculates Central_defender_Defend score
squad_df['cdd_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Jum'] + squad_df['Cmp'] )
squad_df['cdd_green'] = ( squad_df['Hea'] + squad_df['Mar'] + squad_df['Tck'] + squad_df['Pos'] + squad_df['Str'] )
squad_df['cdd_blue'] = ( squad_df['Agg'] + squad_df['Ant'] + squad_df['Bra'] + squad_df['Cnt'] + squad_df['Dec'] )
squad_df['cdd'] =( ( ( squad_df['cdd_key'] * 5) + (squad_df['cdd_green'] * 3) + (squad_df['cdd_blue'] * 1) ) / 40)
squad_df.cdd= squad_df.cdd.round(1)
    


# calculates Central_defender_Stopper score
squad_df['cds_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Jum'] + squad_df['Cmp'] )
squad_df['cds_green'] = ( squad_df['Hea'] + squad_df['Tck'] + squad_df['Agg'] + squad_df['Bra'] + squad_df['Dec'] + squad_df['Pos'] + squad_df['Str'] )
squad_df['cds_blue'] = ( squad_df['Mar'] + squad_df['Ant'] + squad_df['Cnt'] )
squad_df['cds'] =( ( ( squad_df['cds_key'] * 5) + (squad_df['cds_green'] * 3) + (squad_df['cds_blue'] * 1) ) / 44)
squad_df.cds= squad_df.cds.round(1)
    


# calculates Central_defender_Cover score
squad_df['cdc_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Jum'] + squad_df['Cmp'] )
squad_df['cdc_green'] = ( squad_df['Mar'] + squad_df['Tck'] + squad_df['Ant'] + squad_df['Cnt'] + squad_df['Dec'] + squad_df['Pos'] )
squad_df['cdc_blue'] = ( squad_df['Hea'] + squad_df['Bra'] + squad_df['Str'] )
squad_df['cdc'] =( ( ( squad_df['cdc_key'] * 5) + (squad_df['cdc_green'] * 3) + (squad_df['cdc_blue'] * 1) ) / 41)
squad_df.cdc= squad_df.cdc.round(1)
    


# calculates Complete_wing_back_Support score
squad_df['cwbs_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Sta'] + squad_df['Wor'] )
squad_df['cwbs_green'] = ( squad_df['Cro'] + squad_df['Dri'] + squad_df['Tec'] + squad_df['OtB'] + squad_df['Tea'] )
squad_df['cwbs_blue'] = ( squad_df['Fir'] + squad_df['Mar'] + squad_df['Pas'] + squad_df['Tck'] + squad_df['Ant'] + squad_df['Dec'] + squad_df['Fla'] + squad_df['Pos'] + squad_df['Agi'] + squad_df['Bal'] )
squad_df['cwbs'] =( ( ( squad_df['cwbs_key'] * 5) + (squad_df['cwbs_green'] * 3) + (squad_df['cwbs_blue'] * 1) ) / 45)
squad_df.cwbs= squad_df.cwbs.round(1)
    


# calculates Complete_wing_back_Attack score
squad_df['cwba_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Sta'] + squad_df['Wor'] )
squad_df['cwba_green'] = ( squad_df['Cro'] + squad_df['Dri'] + squad_df['Tec'] + squad_df['Fla'] + squad_df['OtB'] + squad_df['Tea'] )
squad_df['cwba_blue'] = ( squad_df['Fir'] + squad_df['Mar'] + squad_df['Pas'] + squad_df['Tck'] + squad_df['Ant'] + squad_df['Dec'] + squad_df['Pos'] + squad_df['Agi'] + squad_df['Bal'] )
squad_df['cwba'] =( ( ( squad_df['cwba_key'] * 5) + (squad_df['cwba_green'] * 3) + (squad_df['cwba_blue'] * 1) ) / 47)
squad_df.cwba= squad_df.cwba.round(1)
    


# calculates Full_back_Defend score
squad_df['fbd_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Sta'] + squad_df['Wor'] )
squad_df['fbd_green'] = ( squad_df['Mar'] + squad_df['Tck'] + squad_df['Ant'] + squad_df['Cnt'] + squad_df['Pos'] + squad_df['Pos'] )
squad_df['fbd_blue'] = ( squad_df['Cro'] + squad_df['Pas'] + squad_df['Dec'] + squad_df['Tea'] )
squad_df['fbd'] =( ( ( squad_df['fbd_key'] * 5) + (squad_df['fbd_green'] * 3) + (squad_df['fbd_blue'] * 1) ) / 42)
squad_df.fbd= squad_df.fbd.round(1)
    


# calculates Full_back_Support score
squad_df['fbs_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Sta'] + squad_df['Wor'] )
squad_df['fbs_green'] = ( squad_df['Mar'] + squad_df['Tck'] + squad_df['Ant'] + squad_df['Cnt'] + squad_df['Pos'] + squad_df['Tea'] )
squad_df['fbs_blue'] = ( squad_df['Cro'] + squad_df['Dri'] + squad_df['Pas'] + squad_df['Tec'] + squad_df['Dec'] )
squad_df['fbs'] =( ( ( squad_df['fbs_key'] * 5) + (squad_df['fbs_green'] * 3) + (squad_df['fbs_blue'] * 1) ) / 43)
squad_df.fbs= squad_df.fbs.round(1)
    


# calculates Full_back_Attack score
squad_df['fba_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Sta'] + squad_df['Wor'] )
squad_df['fba_green'] = ( squad_df['Cro'] + squad_df['Mar'] + squad_df['Tck'] + squad_df['Ant'] + squad_df['Pos'] + squad_df['Tea'] )
squad_df['fba_blue'] = ( squad_df['Dri'] + squad_df['Fir'] + squad_df['Pas'] + squad_df['Tec'] + squad_df['Cnt'] + squad_df['Dec'] + squad_df['OtB'] + squad_df['Agi'] )
squad_df['fba'] =( ( ( squad_df['fba_key'] * 5) + (squad_df['fba_green'] * 3) + (squad_df['fba_blue'] * 1) ) / 46)
squad_df.fba= squad_df.fba.round(1)
    


# calculates Inverted_full_back_Defend score
squad_df['ifbd_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Sta'] + squad_df['Wor'] )
squad_df['ifbd_green'] = ( squad_df['Hea'] + squad_df['Mar'] + squad_df['Tck'] + squad_df['Pos'] + squad_df['Str'] )
squad_df['ifbd_blue'] = ( squad_df['Dri'] + squad_df['Fir'] + squad_df['Pas'] + squad_df['Tec'] + squad_df['Agg'] + squad_df['Ant'] + squad_df['Bra'] + squad_df['Cmp'] + squad_df['Cnt'] + squad_df['Dec'] + squad_df['Agi'] + squad_df['Jum'] )
squad_df['ifbd'] =( ( ( squad_df['ifbd_key'] * 5) + (squad_df['ifbd_green'] * 3) + (squad_df['ifbd_blue'] * 1) ) / 47)
squad_df.ifbd= squad_df.ifbd.round(1)
    


# calculates Inverted_wing_back_Defend score
squad_df['iwbd_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Sta'] + squad_df['Wor'] )
squad_df['iwbd_green'] = ( squad_df['Pas'] + squad_df['Tck'] + squad_df['Ant'] + squad_df['Dec'] + squad_df['Pos'] + squad_df['Tea'] )
squad_df['iwbd_blue'] = ( squad_df['Fir'] + squad_df['Mar'] + squad_df['Tec'] + squad_df['Cmp'] + squad_df['Cnt'] + squad_df['OtB'] + squad_df['Agi'] )
squad_df['iwbd'] =( ( ( squad_df['iwbd_key'] * 5) + (squad_df['iwbd_green'] * 3) + (squad_df['iwbd_blue'] * 1) ) / 45)
squad_df.iwbd= squad_df.iwbd.round(1)
    


# calculates Inverted_wing_back_Support score
squad_df['iwbs_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Sta'] + squad_df['Wor'] )
squad_df['iwbs_green'] = ( squad_df['Fir'] + squad_df['Pas'] + squad_df['Tck'] + squad_df['Cmp'] + squad_df['Dec'] + squad_df['Tea'] )
squad_df['iwbs_blue'] = ( squad_df['Mar'] + squad_df['Tec'] + squad_df['Ant'] + squad_df['Cnt'] + squad_df['OtB'] + squad_df['Pos'] + squad_df['Vis'] + squad_df['Agi'] )
squad_df['iwbs'] =( ( ( squad_df['iwbs_key'] * 5) + (squad_df['iwbs_green'] * 3) + (squad_df['iwbs_blue'] * 1) ) / 46)
squad_df.iwbs= squad_df.iwbs.round(1)
    


# calculates Inverted_wing_back_Attack score
squad_df['iwba_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Sta'] + squad_df['Wor'] )
squad_df['iwba_green'] = ( squad_df['Fir'] + squad_df['Pas'] + squad_df['Tck'] + squad_df['Tec'] + squad_df['Cmp'] + squad_df['Dec'] + squad_df['OtB'] + squad_df['Tea'] + squad_df['Vis'] )
squad_df['iwba_blue'] = ( squad_df['Cro'] + squad_df['Dri'] + squad_df['Lon'] + squad_df['Mar'] + squad_df['Ant'] + squad_df['Cnt'] + squad_df['Fla'] + squad_df['Pos'] + squad_df['Agi'] )
squad_df['iwba'] =( ( ( squad_df['iwba_key'] * 5) + (squad_df['iwba_green'] * 3) + (squad_df['iwba_blue'] * 1) ) / 56)
squad_df.iwba= squad_df.iwba.round(1)
    


# calculates Libero_Defend score
squad_df['ld_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Jum'] + squad_df['Cmp'] )
squad_df['ld_green'] = ( squad_df['Fir'] + squad_df['Hea'] + squad_df['Mar'] + squad_df['Pas'] + squad_df['Tck'] + squad_df['Tec'] + squad_df['Dec'] + squad_df['Pos'] + squad_df['Tea'] + squad_df['Str'] )
squad_df['ld_blue'] = ( squad_df['Ant'] + squad_df['Bra'] + squad_df['Cnt'] + squad_df['Sta'] )
squad_df['ld'] =( ( ( squad_df['ld_key'] * 5) + (squad_df['ld_green'] * 3) + (squad_df['ld_blue'] * 1) ) / 54)
squad_df.ld= squad_df.ld.round(1)
    


# calculates Libero_Support score
squad_df['ls_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Jum'] + squad_df['Cmp'] )
squad_df['ls_green'] = ( squad_df['Fir'] + squad_df['Hea'] + squad_df['Mar'] + squad_df['Pas'] + squad_df['Tck'] + squad_df['Tec'] + squad_df['Dec'] + squad_df['Pos'] + squad_df['Tea'] + squad_df['Str'] )
squad_df['ls_blue'] = ( squad_df['Dri'] + squad_df['Ant'] + squad_df['Bra'] + squad_df['Cnt'] + squad_df['Vis'] + squad_df['Sta'] )
squad_df['ls'] =( ( ( squad_df['ls_key'] * 5) + (squad_df['ls_green'] * 3) + (squad_df['ls_blue'] * 1) ) / 56)
squad_df.ls= squad_df.ls.round(1)
    


# calculates No-nonsense_centre_back_Defend score
squad_df['ncbd_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Jum'] + squad_df['Cmp'] )
squad_df['ncbd_green'] = ( squad_df['Hea'] + squad_df['Mar'] + squad_df['Tck'] + squad_df['Pos'] + squad_df['Str'] )
squad_df['ncbd_blue'] = ( squad_df['Agg'] + squad_df['Ant'] + squad_df['Bra'] + squad_df['Cnt'] )
squad_df['ncbd'] =( ( ( squad_df['ncbd_key'] * 5) + (squad_df['ncbd_green'] * 3) + (squad_df['ncbd_blue'] * 1) ) / 39)
squad_df.ncbd= squad_df.ncbd.round(1)
    


# calculates No-nonsense_centre_back_Stopper score
squad_df['ncbs_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Jum'] + squad_df['Cmp'] )
squad_df['ncbs_green'] = ( squad_df['Hea'] + squad_df['Tck'] + squad_df['Agg'] + squad_df['Bra'] + squad_df['Pos'] + squad_df['Str'] )
squad_df['ncbs_blue'] = ( squad_df['Mar'] + squad_df['Ant'] + squad_df['Cnt'] )
squad_df['ncbs'] =( ( ( squad_df['ncbs_key'] * 5) + (squad_df['ncbs_green'] * 3) + (squad_df['ncbs_blue'] * 1) ) / 41)
squad_df.ncbs= squad_df.ncbs.round(1)
    


# calculates No-nonsense_centre_back_Cover score
squad_df['ncbc_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Jum'] + squad_df['Cmp'] )
squad_df['ncbc_green'] = ( squad_df['Mar'] + squad_df['Tck'] + squad_df['Ant'] + squad_df['Cnt'] + squad_df['Pos'] )
squad_df['ncbc_blue'] = ( squad_df['Hea'] + squad_df['Bra'] + squad_df['Str'] )
squad_df['ncbc'] =( ( ( squad_df['ncbc_key'] * 5) + (squad_df['ncbc_green'] * 3) + (squad_df['ncbc_blue'] * 1) ) / 38)
squad_df.ncbc= squad_df.ncbc.round(1)
    


# calculates No-nonsense_full_back_Defend score
squad_df['nfbd_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Sta'] + squad_df['Wor'] )
squad_df['nfbd_green'] = ( squad_df['Mar'] + squad_df['Tck'] + squad_df['Ant'] + squad_df['Pos'] + squad_df['Str'] )
squad_df['nfbd_blue'] = ( squad_df['Hea'] + squad_df['Agg'] + squad_df['Bra'] + squad_df['Cnt'] + squad_df['Tea'] )
squad_df['nfbd'] =( ( ( squad_df['nfbd_key'] * 5) + (squad_df['nfbd_green'] * 3) + (squad_df['nfbd_blue'] * 1) ) / 40)
squad_df.nfbd= squad_df.nfbd.round(1)
    


# calculates Wide_centre_back_Defend score
squad_df['wcbd_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Jum'] + squad_df['Cmp'] )
squad_df['wcbd_green'] = ( squad_df['Hea'] + squad_df['Mar'] + squad_df['Tck'] + squad_df['Pos'] + squad_df['Str'] )
squad_df['wcbd_blue'] = ( squad_df['Dri'] + squad_df['Fir'] + squad_df['Pas'] + squad_df['Tec'] + squad_df['Agg'] + squad_df['Ant'] + squad_df['Bra'] + squad_df['Cnt'] + squad_df['Dec'] + squad_df['Wor'] + squad_df['Agi'] )
squad_df['wcbd'] =( ( ( squad_df['wcbd_key'] * 5) + (squad_df['wcbd_green'] * 3) + (squad_df['wcbd_blue'] * 1) ) / 46)
squad_df.wcbd= squad_df.wcbd.round(1)
    


# calculates Wide_centre_back_Support score
squad_df['wcbs_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Jum'] + squad_df['Cmp'] )
squad_df['wcbs_green'] = ( squad_df['Dri'] + squad_df['Hea'] + squad_df['Mar'] + squad_df['Tck'] + squad_df['Pos'] + squad_df['Str'] )
squad_df['wcbs_blue'] = ( squad_df['Cro'] + squad_df['Fir'] + squad_df['Pas'] + squad_df['Tec'] + squad_df['Agg'] + squad_df['Ant'] + squad_df['Bra'] + squad_df['Cnt'] + squad_df['Dec'] + squad_df['OtB'] + squad_df['Wor'] + squad_df['Agi'] + squad_df['Sta'] )
squad_df['wcbs'] =( ( ( squad_df['wcbs_key'] * 5) + (squad_df['wcbs_green'] * 3) + (squad_df['wcbs_blue'] * 1) ) / 51)
squad_df.wcbs= squad_df.wcbs.round(1)
    


# calculates Wide_centre_back_Attack score
squad_df['wcba_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Jum'] + squad_df['Cmp'] )
squad_df['wcba_green'] = ( squad_df['Cro'] + squad_df['Dri'] + squad_df['Hea'] + squad_df['Mar'] + squad_df['Tck'] + squad_df['OtB'] + squad_df['Sta'] + squad_df['Str'] )
squad_df['wcba_blue'] = ( squad_df['Fir'] + squad_df['Pas'] + squad_df['Tec'] + squad_df['Agg'] + squad_df['Ant'] + squad_df['Bra'] + squad_df['Cnt'] + squad_df['Dec'] + squad_df['Pos'] + squad_df['Wor'] + squad_df['Agi'] )
squad_df['wcba'] =( ( ( squad_df['wcba_key'] * 5) + (squad_df['wcba_green'] * 3) + (squad_df['wcba_blue'] * 1) ) / 55)
squad_df.wcba= squad_df.wcba.round(1)
    


# calculates Wing_back_Defend score
squad_df['wbd_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Sta'] + squad_df['Wor'] )
squad_df['wbd_green'] = ( squad_df['Mar'] + squad_df['Tck'] + squad_df['Ant'] + squad_df['Pos'] + squad_df['Tea'] )
squad_df['wbd_blue'] = ( squad_df['Cro'] + squad_df['Dri'] + squad_df['Fir'] + squad_df['Pas'] + squad_df['Tec'] + squad_df['Cnt'] + squad_df['Dec'] + squad_df['OtB'] + squad_df['Agi'] + squad_df['Bal'] )
squad_df['wbd'] =( ( ( squad_df['wbd_key'] * 5) + (squad_df['wbd_green'] * 3) + (squad_df['wbd_blue'] * 1) ) / 45)
squad_df.wbd= squad_df.wbd.round(1)
    


# calculates Wing_back_Support score
squad_df['wbs_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Sta'] + squad_df['Wor'] )
squad_df['wbs_green'] = ( squad_df['Cro'] + squad_df['Dri'] + squad_df['Mar'] + squad_df['Tck'] + squad_df['OtB'] + squad_df['Tea'] )
squad_df['wbs_blue'] = ( squad_df['Fir'] + squad_df['Pas'] + squad_df['Tec'] + squad_df['Ant'] + squad_df['Cnt'] + squad_df['Dec'] + squad_df['Pos'] + squad_df['Agi'] + squad_df['Bal'] )
squad_df['wbs'] =( ( ( squad_df['wbs_key'] * 5) + (squad_df['wbs_green'] * 3) + (squad_df['wbs_blue'] * 1) ) / 47)
squad_df.wbs= squad_df.wbs.round(1)
    


# calculates Wing_back_Attack score
squad_df['wba_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Sta'] + squad_df['Wor'] )
squad_df['wba_green'] = ( squad_df['Cro'] + squad_df['Dri'] + squad_df['Tck'] + squad_df['Tec'] + squad_df['OtB'] + squad_df['Tea'] )
squad_df['wba_blue'] = ( squad_df['Fir'] + squad_df['Mar'] + squad_df['Pas'] + squad_df['Ant'] + squad_df['Cnt'] + squad_df['Dec'] + squad_df['Fla'] + squad_df['Pos'] + squad_df['Agi'] + squad_df['Bal'] )
squad_df['wba'] =( ( ( squad_df['wba_key'] * 5) + (squad_df['wba_green'] * 3) + (squad_df['wba_blue'] * 1) ) / 48)
squad_df.wba= squad_df.wba.round(1)
    


# calculates Advanced_playmaker_Support score
squad_df['aps_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Sta'] + squad_df['Wor'] )
squad_df['aps_green'] = ( squad_df['Fir'] + squad_df['Pas'] + squad_df['Tec'] + squad_df['Cmp'] + squad_df['Dec'] + squad_df['OtB'] + squad_df['Tea'] + squad_df['Vis'] )
squad_df['aps_blue'] = ( squad_df['Dri'] + squad_df['Ant'] + squad_df['Fla'] + squad_df['Agi'] )
squad_df['aps'] =( ( ( squad_df['aps_key'] * 5) + (squad_df['aps_green'] * 3) + (squad_df['aps_blue'] * 1) ) / 48)
squad_df.aps= squad_df.aps.round(1)
    


# calculates Advanced_playmaker_Attack score
squad_df['apa_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Sta'] + squad_df['Wor'] )
squad_df['apa_green'] = ( squad_df['Fir'] + squad_df['Pas'] + squad_df['Tec'] + squad_df['Cmp'] + squad_df['Dec'] + squad_df['OtB'] + squad_df['Tea'] + squad_df['Vis'] )
squad_df['apa_blue'] = ( squad_df['Dri'] + squad_df['Ant'] + squad_df['Fla'] + squad_df['Agi'] )
squad_df['apa'] =( ( ( squad_df['apa_key'] * 5) + (squad_df['apa_green'] * 3) + (squad_df['apa_blue'] * 1) ) / 48)
squad_df.apa= squad_df.apa.round(1)
    


# calculates Anchor_Defend score
squad_df['ad_key'] = ( squad_df['Wor'] + squad_df['Sta'] + squad_df['Acc'] + squad_df['Pac'] )
squad_df['ad_green'] = ( squad_df['Mar'] + squad_df['Tck'] + squad_df['Ant'] + squad_df['Cnt'] + squad_df['Dec'] + squad_df['Pos'] )
squad_df['ad_blue'] = ( squad_df['Cmp'] + squad_df['Tea'] + squad_df['Str'] )
squad_df['ad'] =( ( ( squad_df['ad_key'] * 5) + (squad_df['ad_green'] * 3) + (squad_df['ad_blue'] * 1) ) / 41)
squad_df.ad= squad_df.ad.round(1)
    


# calculates Attacking_midfielder_Support score
squad_df['ams_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Sta'] + squad_df['Wor'] )
squad_df['ams_green'] = ( squad_df['Fir'] + squad_df['Lon'] + squad_df['Pas'] + squad_df['Tec'] + squad_df['Ant'] + squad_df['Dec'] + squad_df['Fla'] + squad_df['OtB'] )
squad_df['ams_blue'] = ( squad_df['Dri'] + squad_df['Cmp'] + squad_df['Vis'] + squad_df['Agi'] )
squad_df['ams'] =( ( ( squad_df['ams_key'] * 5) + (squad_df['ams_green'] * 3) + (squad_df['ams_blue'] * 1) ) / 48)
squad_df.ams= squad_df.ams.round(1)
    


# calculates Attacking_midfielder_Attack score
squad_df['ama_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Sta'] + squad_df['Wor'] )
squad_df['ama_green'] = ( squad_df['Dri'] + squad_df['Fir'] + squad_df['Lon'] + squad_df['Pas'] + squad_df['Tec'] + squad_df['Ant'] + squad_df['Dec'] + squad_df['Fla'] + squad_df['OtB'] )
squad_df['ama_blue'] = ( squad_df['Fin'] + squad_df['Cmp'] + squad_df['Vis'] + squad_df['Agi'] )
squad_df['ama'] =( ( ( squad_df['ama_key'] * 5) + (squad_df['ama_green'] * 3) + (squad_df['ama_blue'] * 1) ) / 51)
squad_df.ama= squad_df.ama.round(1)
    


# calculates Ball_winning_midfielder_Defend score
squad_df['bwmd_key'] = ( squad_df['Wor'] + squad_df['Sta'] + squad_df['Acc'] + squad_df['Pac'] )
squad_df['bwmd_green'] = ( squad_df['Tck'] + squad_df['Agg'] + squad_df['Ant'] + squad_df['Tea'] )
squad_df['bwmd_blue'] = ( squad_df['Mar'] + squad_df['Bra'] + squad_df['Cnt'] + squad_df['Pos'] + squad_df['Agi'] + squad_df['Str'] )
squad_df['bwmd'] =( ( ( squad_df['bwmd_key'] * 5) + (squad_df['bwmd_green'] * 3) + (squad_df['bwmd_blue'] * 1) ) / 38)
squad_df.bwmd= squad_df.bwmd.round(1)
    


# calculates Ball_winning_midfielder_Support score
squad_df['bwms_key'] = ( squad_df['Wor'] + squad_df['Sta'] + squad_df['Acc'] + squad_df['Pac'] )
squad_df['bwms_green'] = ( squad_df['Tck'] + squad_df['Agg'] + squad_df['Ant'] + squad_df['Tea'] )
squad_df['bwms_blue'] = ( squad_df['Mar'] + squad_df['Pas'] + squad_df['Bra'] + squad_df['Cnt'] + squad_df['Agi'] + squad_df['Str'] )
squad_df['bwms'] =( ( ( squad_df['bwms_key'] * 5) + (squad_df['bwms_green'] * 3) + (squad_df['bwms_blue'] * 1) ) / 38)
squad_df.bwms= squad_df.bwms.round(1)
    


# calculates Box_to_box_midfielder_Support score
squad_df['b2bs_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Sta'] + squad_df['Wor'] )
squad_df['b2bs_green'] = ( squad_df['Pas'] + squad_df['Tck'] + squad_df['OtB'] + squad_df['Tea'] )
squad_df['b2bs_blue'] = ( squad_df['Dri'] + squad_df['Fin'] + squad_df['Fir'] + squad_df['Lon'] + squad_df['Tec'] + squad_df['Agg'] + squad_df['Ant'] + squad_df['Cmp'] + squad_df['Dec'] + squad_df['Pos'] + squad_df['Bal'] + squad_df['Str'] )
squad_df['b2bs'] =( ( ( squad_df['b2bs_key'] * 5) + (squad_df['b2bs_green'] * 3) + (squad_df['b2bs_blue'] * 1) ) / 44)
squad_df.b2bs= squad_df.b2bs.round(1)
    


# calculates Carrilero_Support score
squad_df['cars_key'] = ( squad_df['Wor'] + squad_df['Sta'] + squad_df['Acc'] + squad_df['Pac'] )
squad_df['cars_green'] = ( squad_df['Fir'] + squad_df['Pas'] + squad_df['Tck'] + squad_df['Dec'] + squad_df['Pos'] + squad_df['Tea'] )
squad_df['cars_blue'] = ( squad_df['Tec'] + squad_df['Ant'] + squad_df['Cmp'] + squad_df['Cnt'] + squad_df['OtB'] + squad_df['Vis'] )
squad_df['cars'] =( ( ( squad_df['cars_key'] * 5) + (squad_df['cars_green'] * 3) + (squad_df['cars_blue'] * 1) ) / 44)
squad_df.cars= squad_df.cars.round(1)
    


# calculates Central_midfielder_Defend score
squad_df['cmd_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Sta'] + squad_df['Wor'] )
squad_df['cmd_green'] = ( squad_df['Tck'] + squad_df['Cnt'] + squad_df['Dec'] + squad_df['Pos'] + squad_df['Tea'] )
squad_df['cmd_blue'] = ( squad_df['Fir'] + squad_df['Mar'] + squad_df['Pas'] + squad_df['Tec'] + squad_df['Agg'] + squad_df['Ant'] + squad_df['Cmp'] )
squad_df['cmd'] =( ( ( squad_df['cmd_key'] * 5) + (squad_df['cmd_green'] * 3) + (squad_df['cmd_blue'] * 1) ) / 42)
squad_df.cmd= squad_df.cmd.round(1)
    


# calculates Central_midfielder_Support score
squad_df['cms_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Sta'] + squad_df['Wor'] )
squad_df['cms_green'] = ( squad_df['Fir'] + squad_df['Pas'] + squad_df['Tck'] + squad_df['Dec'] + squad_df['Tea'] )
squad_df['cms_blue'] = ( squad_df['Tec'] + squad_df['Ant'] + squad_df['Cmp'] + squad_df['Cnt'] + squad_df['OtB'] + squad_df['Vis'] )
squad_df['cms'] =( ( ( squad_df['cms_key'] * 5) + (squad_df['cms_green'] * 3) + (squad_df['cms_blue'] * 1) ) / 41)
squad_df.cms= squad_df.cms.round(1)
    


# calculates Central_midfielder_Attack score
squad_df['cma_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Sta'] + squad_df['Wor'] )
squad_df['cma_green'] = ( squad_df['Fir'] + squad_df['Pas'] + squad_df['Dec'] + squad_df['OtB'] )
squad_df['cma_blue'] = ( squad_df['Lon'] + squad_df['Tck'] + squad_df['Tec'] + squad_df['Ant'] + squad_df['Cmp'] + squad_df['Tea'] + squad_df['Vis'] )
squad_df['cma'] =( ( ( squad_df['cma_key'] * 5) + (squad_df['cma_green'] * 3) + (squad_df['cma_blue'] * 1) ) / 39)
squad_df.cma= squad_df.cma.round(1)
    


# calculates Deep_lying_playmaker_Defend score
squad_df['dlpd_key'] = ( squad_df['Wor'] + squad_df['Sta'] + squad_df['Acc'] + squad_df['Pac'] )
squad_df['dlpd_green'] = ( squad_df['Fir'] + squad_df['Pas'] + squad_df['Tec'] + squad_df['Cmp'] + squad_df['Dec'] + squad_df['Tea'] + squad_df['Vis'] )
squad_df['dlpd_blue'] = ( squad_df['Tck'] + squad_df['Ant'] + squad_df['Pos'] + squad_df['Bal'] )
squad_df['dlpd'] =( ( ( squad_df['dlpd_key'] * 5) + (squad_df['dlpd_green'] * 3) + (squad_df['dlpd_blue'] * 1) ) / 45)
squad_df.dlpd= squad_df.dlpd.round(1)
    


# calculates Deep_lying_playmaker_Support score
squad_df['dlps_key'] = ( squad_df['Wor'] + squad_df['Sta'] + squad_df['Acc'] + squad_df['Pac'] )
squad_df['dlps_green'] = ( squad_df['Fir'] + squad_df['Pas'] + squad_df['Tec'] + squad_df['Cmp'] + squad_df['Dec'] + squad_df['Tea'] + squad_df['Vis'] )
squad_df['dlps_blue'] = ( squad_df['Ant'] + squad_df['OtB'] + squad_df['Pos'] + squad_df['Bal'] )
squad_df['dlps'] =( ( ( squad_df['dlps_key'] * 5) + (squad_df['dlps_green'] * 3) + (squad_df['dlps_blue'] * 1) ) / 45)
squad_df.dlps= squad_df.dlps.round(1)
    


# calculates Defensive_midfielder_Defend score
squad_df['dmd_key'] = ( squad_df['Wor'] + squad_df['Sta'] + squad_df['Acc'] + squad_df['Pac'] )
squad_df['dmd_green'] = ( squad_df['Tck'] + squad_df['Ant'] + squad_df['Cnt'] + squad_df['Pos'] + squad_df['Tea'] )
squad_df['dmd_blue'] = ( squad_df['Mar'] + squad_df['Pas'] + squad_df['Agg'] + squad_df['Cmp'] + squad_df['Str'] + squad_df['Dec'] )
squad_df['dmd'] =( ( ( squad_df['dmd_key'] * 5) + (squad_df['dmd_green'] * 3) + (squad_df['dmd_blue'] * 1) ) / 41)
squad_df.dmd= squad_df.dmd.round(1)
    


# calculates Defensive_midfielder_Support score
squad_df['dms_key'] = ( squad_df['Wor'] + squad_df['Sta'] + squad_df['Acc'] + squad_df['Pac'] )
squad_df['dms_green'] = ( squad_df['Tck'] + squad_df['Ant'] + squad_df['Cnt'] + squad_df['Pos'] + squad_df['Tea'] )
squad_df['dms_blue'] = ( squad_df['Fir'] + squad_df['Mar'] + squad_df['Pas'] + squad_df['Agg'] + squad_df['Cmp'] + squad_df['Dec'] + squad_df['Str'] )
squad_df['dms'] =( ( ( squad_df['dms_key'] * 5) + (squad_df['dms_green'] * 3) + (squad_df['dms_blue'] * 1) ) / 42)
squad_df.dms= squad_df.dms.round(1)
    


# calculates Defensive_winger_Defend score
squad_df['dwd_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Sta'] + squad_df['Wor'] )
squad_df['dwd_green'] = ( squad_df['Tec'] + squad_df['Ant'] + squad_df['OtB'] + squad_df['Pos'] + squad_df['Tea'] )
squad_df['dwd_blue'] = ( squad_df['Cro'] + squad_df['Dri'] + squad_df['Fir'] + squad_df['Mar'] + squad_df['Tck'] + squad_df['Agg'] + squad_df['Cnt'] + squad_df['Dec'] )
squad_df['dwd'] =( ( ( squad_df['dwd_key'] * 5) + (squad_df['dwd_green'] * 3) + (squad_df['dwd_blue'] * 1) ) / 43)
squad_df.dwd= squad_df.dwd.round(1)
    


# calculates Defensive_winger_Support score
squad_df['dws_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Sta'] + squad_df['Wor'] )
squad_df['dws_green'] = ( squad_df['Cro'] + squad_df['Pas'] + squad_df['Tec'] + squad_df['OtB'] + squad_df['Tea'] )
squad_df['dws_blue'] = ( squad_df['Dri'] + squad_df['Fir'] + squad_df['Mar'] + squad_df['Pas'] + squad_df['Tck'] + squad_df['Agg'] + squad_df['Ant'] + squad_df['Cmp'] + squad_df['Cnt'] + squad_df['Dec'] + squad_df['Pos'] )
squad_df['dws'] =( ( ( squad_df['dws_key'] * 5) + (squad_df['dws_green'] * 3) + (squad_df['dws_blue'] * 1) ) / 46)
squad_df.dws= squad_df.dws.round(1)
    


# calculates Enganche_Support score
squad_df['engs_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Sta'] + squad_df['Wor'] )
squad_df['engs_green'] = ( squad_df['Fir'] + squad_df['Pas'] + squad_df['Tec'] + squad_df['Cmp'] + squad_df['Dec'] + squad_df['Vis'] )
squad_df['engs_blue'] = ( squad_df['Dri'] + squad_df['Ant'] + squad_df['Fla'] + squad_df['OtB'] + squad_df['Tea'] + squad_df['Agi'] )
squad_df['engs'] =( ( ( squad_df['engs_key'] * 5) + (squad_df['engs_green'] * 3) + (squad_df['engs_blue'] * 1) ) / 44)
squad_df.engs= squad_df.engs.round(1)
    


# calculates Half_back_Defend score
squad_df['hbd_key'] = ( squad_df['Wor'] + squad_df['Sta'] + squad_df['Acc'] + squad_df['Pac'] )
squad_df['hbd_green'] = ( squad_df['Mar'] + squad_df['Tck'] + squad_df['Ant'] + squad_df['Cmp'] + squad_df['Cnt'] + squad_df['Dec'] + squad_df['Pos'] + squad_df['Tea'] )
squad_df['hbd_blue'] = ( squad_df['Fir'] + squad_df['Pas'] + squad_df['Agg'] + squad_df['Bra'] + squad_df['Jum'] + squad_df['Str'] )
squad_df['hbd'] =( ( ( squad_df['hbd_key'] * 5) + (squad_df['hbd_green'] * 3) + (squad_df['hbd_blue'] * 1) ) / 50)
squad_df.hbd= squad_df.hbd.round(1)
    


# calculates Inside_forward_Support score
squad_df['ifs_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Sta'] + squad_df['Wor'] )
squad_df['ifs_green'] = ( squad_df['Dri'] + squad_df['Fin'] + squad_df['Fir'] + squad_df['Tec'] + squad_df['OtB'] + squad_df['Agi'] )
squad_df['ifs_blue'] = ( squad_df['Lon'] + squad_df['Pas'] + squad_df['Ant'] + squad_df['Cmp'] + squad_df['Fla'] + squad_df['Vis'] + squad_df['Bal'] )
squad_df['ifs'] =( ( ( squad_df['ifs_key'] * 5) + (squad_df['ifs_green'] * 3) + (squad_df['ifs_blue'] * 1) ) / 45)
squad_df.ifs= squad_df.ifs.round(1)
    


# calculates Inside_forward_Attack score
squad_df['ifa_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Sta'] + squad_df['Wor'] )
squad_df['ifa_green'] = ( squad_df['Dri'] + squad_df['Fin'] + squad_df['Fir'] + squad_df['Tec'] + squad_df['Ant'] + squad_df['OtB'] + squad_df['Agi'] )
squad_df['ifa_blue'] = ( squad_df['Lon'] + squad_df['Pas'] + squad_df['Cmp'] + squad_df['Fla'] + squad_df['Bal'] )
squad_df['ifa'] =( ( ( squad_df['ifa_key'] * 5) + (squad_df['ifa_green'] * 3) + (squad_df['ifa_blue'] * 1) ) / 46)
squad_df.ifa= squad_df.ifa.round(1)
    


# calculates Inverted_winger_Support score
squad_df['iws_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Sta'] + squad_df['Wor'] )
squad_df['iws_green'] = ( squad_df['Cro'] + squad_df['Dri'] + squad_df['Pas'] + squad_df['Tec'] + squad_df['Agi'] )
squad_df['iws_blue'] = ( squad_df['Fir'] + squad_df['Lon'] + squad_df['Cmp'] + squad_df['Dec'] + squad_df['OtB'] + squad_df['Vis'] + squad_df['Bal'] )
squad_df['iws'] =( ( ( squad_df['iws_key'] * 5) + (squad_df['iws_green'] * 3) + (squad_df['iws_blue'] * 1) ) / 42)
squad_df.iws= squad_df.iws.round(1)
    


# calculates Inverted_winger_Attack score
squad_df['iwa_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Sta'] + squad_df['Wor'] )
squad_df['iwa_green'] = ( squad_df['Cro'] + squad_df['Dri'] + squad_df['Pas'] + squad_df['Tec'] + squad_df['Agi'] )
squad_df['iwa_blue'] = ( squad_df['Fir'] + squad_df['Lon'] + squad_df['Ant'] + squad_df['Cmp'] + squad_df['Dec'] + squad_df['Fla'] + squad_df['OtB'] + squad_df['Vis'] + squad_df['Bal'] )
squad_df['iwa'] =( ( ( squad_df['iwa_key'] * 5) + (squad_df['iwa_green'] * 3) + (squad_df['iwa_blue'] * 1) ) / 44)
squad_df.iwa= squad_df.iwa.round(1)
    


# calculates Mezzala_Support score
squad_df['mezs_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Sta'] + squad_df['Wor'] )
squad_df['mezs_green'] = ( squad_df['Pas'] + squad_df['Tec'] + squad_df['Dec'] + squad_df['OtB'] )
squad_df['mezs_blue'] = ( squad_df['Dri'] + squad_df['Fir'] + squad_df['Lon'] + squad_df['Tck'] + squad_df['Ant'] + squad_df['Cmp'] + squad_df['Vis'] + squad_df['Bal'] )
squad_df['mezs'] =( ( ( squad_df['mezs_key'] * 5) + (squad_df['mezs_green'] * 3) + (squad_df['mezs_blue'] * 1) ) / 40)
squad_df.mezs= squad_df.mezs.round(1)
    


# calculates Mezzala_Attack score
squad_df['meza_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Sta'] + squad_df['Wor'] )
squad_df['meza_green'] = ( squad_df['Dri'] + squad_df['Pas'] + squad_df['Tec'] + squad_df['Dec'] + squad_df['OtB'] + squad_df['Vis'] )
squad_df['meza_blue'] = ( squad_df['Fin'] + squad_df['Fir'] + squad_df['Lon'] + squad_df['Ant'] + squad_df['Cmp'] + squad_df['Fla'] + squad_df['Bal'] )
squad_df['meza'] =( ( ( squad_df['meza_key'] * 5) + (squad_df['meza_green'] * 3) + (squad_df['meza_blue'] * 1) ) / 45)
squad_df.meza= squad_df.meza.round(1)
    


# calculates Raumdeuter_Attack score
squad_df['raua_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Sta'] + squad_df['Wor'] )
squad_df['raua_green'] = ( squad_df['Fin'] + squad_df['Ant'] + squad_df['Cmp'] + squad_df['Cnt'] + squad_df['Dec'] + squad_df['OtB'] + squad_df['Bal'] )
squad_df['raua_blue'] = ( squad_df['Fir'] + squad_df['Tec'] )
squad_df['raua'] =( ( ( squad_df['raua_key'] * 5) + (squad_df['raua_green'] * 3) + (squad_df['raua_blue'] * 1) ) / 43)
squad_df.raua= squad_df.raua.round(1)
    


# calculates Regista_Support score
squad_df['regs_key'] = ( squad_df['Wor'] + squad_df['Sta'] + squad_df['Acc'] + squad_df['Pac'] )
squad_df['regs_green'] = ( squad_df['Fir'] + squad_df['Pas'] + squad_df['Tec'] + squad_df['Cmp'] + squad_df['Dec'] + squad_df['Fla'] + squad_df['OtB'] + squad_df['Tea'] + squad_df['Vis'] )
squad_df['regs_blue'] = ( squad_df['Dri'] + squad_df['Lon'] + squad_df['Ant'] + squad_df['Bal'] )
squad_df['regs'] =( ( ( squad_df['regs_key'] * 5) + (squad_df['regs_green'] * 3) + (squad_df['regs_blue'] * 1) ) / 51)
squad_df.regs= squad_df.regs.round(1)
    


# calculates Roaming_playmaker_Support score
squad_df['rps_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Sta'] + squad_df['Wor'] )
squad_df['rps_green'] = ( squad_df['Fir'] + squad_df['Pas'] + squad_df['Tec'] + squad_df['Ant'] + squad_df['Cmp'] + squad_df['Dec'] + squad_df['OtB'] + squad_df['Tea'] + squad_df['Vis'] )
squad_df['rps_blue'] = ( squad_df['Dri'] + squad_df['Lon'] + squad_df['Cnt'] + squad_df['Pos'] + squad_df['Agi'] + squad_df['Bal'] )
squad_df['rps'] =( ( ( squad_df['rps_key'] * 5) + (squad_df['rps_green'] * 3) + (squad_df['rps_blue'] * 1) ) / 53)
squad_df.rps= squad_df.rps.round(1)
    


# calculates Segundo_volante_Support score
squad_df['svs_key'] = ( squad_df['Wor'] + squad_df['Sta'] + squad_df['Acc'] + squad_df['Pac'] )
squad_df['svs_green'] = ( squad_df['Mar'] + squad_df['Pas'] + squad_df['Tck'] + squad_df['OtB'] + squad_df['Pos'] )
squad_df['svs_blue'] = ( squad_df['Fin'] + squad_df['Fir'] + squad_df['Lon'] + squad_df['Ant'] + squad_df['Cmp'] + squad_df['Cnt'] + squad_df['Dec'] + squad_df['Bal'] + squad_df['Str'] )
squad_df['svs'] =( ( ( squad_df['svs_key'] * 5) + (squad_df['svs_green'] * 3) + (squad_df['svs_blue'] * 1) ) / 44)
squad_df.svs= squad_df.svs.round(1)
    


# calculates Segundo_volante_Attack score
squad_df['sva_key'] = ( squad_df['Wor'] + squad_df['Sta'] + squad_df['Acc'] + squad_df['Pac'] )
squad_df['sva_green'] = ( squad_df['Fin'] + squad_df['Lon'] + squad_df['Pas'] + squad_df['Tck'] + squad_df['Ant'] + squad_df['OtB'] + squad_df['Pos'] )
squad_df['sva_blue'] = ( squad_df['Fir'] + squad_df['Mar'] + squad_df['Cmp'] + squad_df['Cnt'] + squad_df['Dec'] + squad_df['Bal'] )
squad_df['sva'] =( ( ( squad_df['sva_key'] * 5) + (squad_df['sva_green'] * 3) + (squad_df['sva_blue'] * 1) ) / 47)
squad_df.sva= squad_df.sva.round(1)
    


# calculates Shadow_striker_Attack score
squad_df['ssa_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Sta'] + squad_df['Wor'] )
squad_df['ssa_green'] = ( squad_df['Dri'] + squad_df['Fin'] + squad_df['Fir'] + squad_df['Ant'] + squad_df['Cmp'] + squad_df['OtB'] )
squad_df['ssa_blue'] = ( squad_df['Pas'] + squad_df['Tec'] + squad_df['Cnt'] + squad_df['Dec'] + squad_df['Agi'] + squad_df['Bal'] )
squad_df['ssa'] =( ( ( squad_df['ssa_key'] * 5) + (squad_df['ssa_green'] * 3) + (squad_df['ssa_blue'] * 1) ) / 44)
squad_df.ssa= squad_df.ssa.round(1)
    


# calculates Wide_midfielder_Defend score
squad_df['wmd_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Sta'] + squad_df['Wor'] )
squad_df['wmd_green'] = ( squad_df['Pas'] + squad_df['Tck'] + squad_df['Cnt'] + squad_df['Dec'] + squad_df['Pos'] + squad_df['Tea'] )
squad_df['wmd_blue'] = ( squad_df['Cro'] + squad_df['Fir'] + squad_df['Mar'] + squad_df['Tec'] + squad_df['Ant'] + squad_df['Cmp'] )
squad_df['wmd'] =( ( ( squad_df['wmd_key'] * 5) + (squad_df['wmd_green'] * 3) + (squad_df['wmd_blue'] * 1) ) / 44)
squad_df.wmd= squad_df.wmd.round(1)
    


# calculates Wide_midfielder_Support score
squad_df['wms_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Sta'] + squad_df['Wor'] )
squad_df['wms_green'] = ( squad_df['Pas'] + squad_df['Tck'] + squad_df['Dec'] + squad_df['Tea'] )
squad_df['wms_blue'] = ( squad_df['Cro'] + squad_df['Fir'] + squad_df['Tec'] + squad_df['Ant'] + squad_df['Cmp'] + squad_df['Cnt'] + squad_df['OtB'] + squad_df['Pos'] + squad_df['Vis'] )
squad_df['wms'] =( ( ( squad_df['wms_key'] * 5) + (squad_df['wms_green'] * 3) + (squad_df['wms_blue'] * 1) ) / 41)
squad_df.wms= squad_df.wms.round(1)
    


# calculates Wide_midfielder_Attack score
squad_df['wma_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Sta'] + squad_df['Wor'] )
squad_df['wma_green'] = ( squad_df['Cro'] + squad_df['Fir'] + squad_df['Pas'] + squad_df['Dec'] + squad_df['Tea'] )
squad_df['wma_blue'] = ( squad_df['Tck'] + squad_df['Tec'] + squad_df['Ant'] + squad_df['Cmp'] + squad_df['OtB'] + squad_df['Vis'] )
squad_df['wma'] =( ( ( squad_df['wma_key'] * 5) + (squad_df['wma_green'] * 3) + (squad_df['wma_blue'] * 1) ) / 41)
squad_df.wma= squad_df.wma.round(1)
    


# calculates Wide_playmaker_Support score
squad_df['wps_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Sta'] + squad_df['Wor'] )
squad_df['wps_green'] = ( squad_df['Fir'] + squad_df['Pas'] + squad_df['Tec'] + squad_df['Cmp'] + squad_df['Dec'] + squad_df['Tea'] + squad_df['Vis'] )
squad_df['wps_blue'] = ( squad_df['Dri'] + squad_df['OtB'] + squad_df['Agi'] )
squad_df['wps'] =( ( ( squad_df['wps_key'] * 5) + (squad_df['wps_green'] * 3) + (squad_df['wps_blue'] * 1) ) / 44)
squad_df.wps= squad_df.wps.round(1)
    


# calculates Wide_playmaker_Attack score
squad_df['wpa_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Sta'] + squad_df['Wor'] )
squad_df['wpa_green'] = ( squad_df['Dri'] + squad_df['Fir'] + squad_df['Pas'] + squad_df['Tec'] + squad_df['Cmp'] + squad_df['Dec'] + squad_df['OtB'] + squad_df['Tea'] + squad_df['Vis'] )
squad_df['wpa_blue'] = ( squad_df['Ant'] + squad_df['Fla'] + squad_df['Agi'] )
squad_df['wpa'] =( ( ( squad_df['wpa_key'] * 5) + (squad_df['wpa_green'] * 3) + (squad_df['wpa_blue'] * 1) ) / 50)
squad_df.wpa= squad_df.wpa.round(1)
    


# calculates Wide_target_forward_Support score
squad_df['wtfs_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Sta'] + squad_df['Wor'] )
squad_df['wtfs_green'] = ( squad_df['Hea'] + squad_df['Bra'] + squad_df['Tea'] + squad_df['Jum'] + squad_df['Str'] )
squad_df['wtfs_blue'] = ( squad_df['Cro'] + squad_df['Fir'] + squad_df['Ant'] + squad_df['OtB'] + squad_df['Bal'] )
squad_df['wtfs'] =( ( ( squad_df['wtfs_key'] * 5) + (squad_df['wtfs_green'] * 3) + (squad_df['wtfs_blue'] * 1) ) / 40)
squad_df.wtfs= squad_df.wtfs.round(1)
    


# calculates Wide_target_forward_Attack score
squad_df['wtfa_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Sta'] + squad_df['Wor'] )
squad_df['wtfa_green'] = ( squad_df['Hea'] + squad_df['Bra'] + squad_df['OtB'] + squad_df['Jum'] + squad_df['Str'] )
squad_df['wtfa_blue'] = ( squad_df['Cro'] + squad_df['Fin'] + squad_df['Fir'] + squad_df['Ant'] + squad_df['Tea'] + squad_df['Bal'] )
squad_df['wtfa'] =( ( ( squad_df['wtfa_key'] * 5) + (squad_df['wtfa_green'] * 3) + (squad_df['wtfa_blue'] * 1) ) / 41)
squad_df.wtfa= squad_df.wtfa.round(1)
    


# calculates Winger_Support score
squad_df['ws_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Sta'] + squad_df['Wor'] )
squad_df['ws_green'] = ( squad_df['Cro'] + squad_df['Dri'] + squad_df['Tec'] + squad_df['Agi'] )
squad_df['ws_blue'] = ( squad_df['Fir'] + squad_df['Pas'] + squad_df['OtB'] + squad_df['Bal'] )
squad_df['ws'] =( ( ( squad_df['ws_key'] * 5) + (squad_df['ws_green'] * 3) + (squad_df['ws_blue'] * 1) ) / 36)
squad_df.ws= squad_df.ws.round(1)
    


# calculates Winger_Attack score
squad_df['wa_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Sta'] + squad_df['Wor'] )
squad_df['wa_green'] = ( squad_df['Cro'] + squad_df['Dri'] + squad_df['Tec'] + squad_df['Agi'] )
squad_df['wa_blue'] = ( squad_df['Fir'] + squad_df['Pas'] + squad_df['Ant'] + squad_df['Fla'] + squad_df['OtB'] + squad_df['Bal'] )
squad_df['wa'] =( ( ( squad_df['wa_key'] * 5) + (squad_df['wa_green'] * 3) + (squad_df['wa_blue'] * 1) ) / 38)
squad_df.wa= squad_df.wa.round(1)
    


# calculates Advanced_forward_Attack score
squad_df['afa_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Fin'] )
squad_df['afa_green'] = ( squad_df['Dri'] + squad_df['Fir'] + squad_df['Tec'] + squad_df['Cmp'] + squad_df['OtB'] )
squad_df['afa_blue'] = ( squad_df['Pas'] + squad_df['Ant'] + squad_df['Dec'] + squad_df['Wor'] + squad_df['Agi'] + squad_df['Bal'] + squad_df['Sta'] )
squad_df['afa'] =( ( ( squad_df['afa_key'] * 5) + (squad_df['afa_green'] * 3) + (squad_df['afa_blue'] * 1) ) / 37)
squad_df.afa= squad_df.afa.round(1)
    


# calculates Complete_forward_Support score
squad_df['cfs_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Fin'] )
squad_df['cfs_green'] = ( squad_df['Dri'] + squad_df['Fir'] + squad_df['Hea'] + squad_df['Lon'] + squad_df['Pas'] + squad_df['Tec'] + squad_df['Ant'] + squad_df['Cmp'] + squad_df['Dec'] + squad_df['OtB'] + squad_df['Vis'] + squad_df['Agi'] + squad_df['Str'] )
squad_df['cfs_blue'] = ( squad_df['Tea'] + squad_df['Wor'] + squad_df['Bal'] + squad_df['Jum'] + squad_df['Sta'] )
squad_df['cfs'] =( ( ( squad_df['cfs_key'] * 5) + (squad_df['cfs_green'] * 3) + (squad_df['cfs_blue'] * 1) ) / 59)
squad_df.cfs= squad_df.cfs.round(1)
    


# calculates Complete_forward_Attack score
squad_df['cfa_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Fin'] )
squad_df['cfa_green'] = ( squad_df['Dri'] + squad_df['Fir'] + squad_df['Hea'] + squad_df['Tec'] + squad_df['Ant'] + squad_df['Cmp'] + squad_df['OtB'] + squad_df['Agi'] + squad_df['Str'] )
squad_df['cfa_blue'] = ( squad_df['Lon'] + squad_df['Pas'] + squad_df['Dec'] + squad_df['Tea'] + squad_df['Vis'] + squad_df['Wor'] + squad_df['Bal'] + squad_df['Jum'] + squad_df['Sta'] )
squad_df['cfa'] =( ( ( squad_df['cfa_key'] * 5) + (squad_df['cfa_green'] * 3) + (squad_df['cfa_blue'] * 1) ) / 51)
squad_df.cfa= squad_df.cfa.round(1)
    


# calculates Deep_lying_forward_Support score
squad_df['dlfs_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Fin'] )
squad_df['dlfs_green'] = ( squad_df['Fir'] + squad_df['Pas'] + squad_df['Tec'] + squad_df['Cmp'] + squad_df['Dec'] + squad_df['OtB'] + squad_df['Tea'] )
squad_df['dlfs_blue'] = ( squad_df['Ant'] + squad_df['Fla'] + squad_df['Vis'] + squad_df['Bal'] + squad_df['Str'] )
squad_df['dlfs'] =( ( ( squad_df['dlfs_key'] * 5) + (squad_df['dlfs_green'] * 3) + (squad_df['dlfs_blue'] * 1) ) / 41)
squad_df.dlfs= squad_df.dlfs.round(1)
    


# calculates Deep_lying_forward_Attack score
squad_df['dlfa_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Fin'] )
squad_df['dlfa_green'] = ( squad_df['Fir'] + squad_df['Pas'] + squad_df['Tec'] + squad_df['Cmp'] + squad_df['Dec'] + squad_df['OtB'] + squad_df['Tea'] )
squad_df['dlfa_blue'] = ( squad_df['Dri'] + squad_df['Ant'] + squad_df['Fla'] + squad_df['Vis'] + squad_df['Bal'] + squad_df['Str'] )
squad_df['dlfa'] =( ( ( squad_df['dlfa_key'] * 5) + (squad_df['dlfa_green'] * 3) + (squad_df['dlfa_blue'] * 1) ) / 42)
squad_df.dlfa= squad_df.dlfa.round(1)
    


# calculates False_nine_Support score
squad_df['f9s_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Fin'] )
squad_df['f9s_green'] = ( squad_df['Dri'] + squad_df['Fir'] + squad_df['Pas'] + squad_df['Tec'] + squad_df['Cmp'] + squad_df['Dec'] + squad_df['OtB'] + squad_df['Vis'] + squad_df['Agi'] )
squad_df['f9s_blue'] = ( squad_df['Ant'] + squad_df['Fla'] + squad_df['Tea'] + squad_df['Bal'] )
squad_df['f9s'] =( ( ( squad_df['f9s_key'] * 5) + (squad_df['f9s_green'] * 3) + (squad_df['f9s_blue'] * 1) ) / 46)
squad_df.f9s= squad_df.f9s.round(1)
    


# calculates Poacher_Attack score
squad_df['pa_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Fin'] )
squad_df['pa_green'] = ( squad_df['Ant'] + squad_df['Cmp'] + squad_df['OtB'] )
squad_df['pa_blue'] = ( squad_df['Fir'] + squad_df['Hea'] + squad_df['Tec'] + squad_df['Dec'] )
squad_df['pa'] =( ( ( squad_df['pa_key'] * 5) + (squad_df['pa_green'] * 3) + (squad_df['pa_blue'] * 1) ) / 28)
squad_df.pa= squad_df.pa.round(1)
    


# calculates Pressing_forward_Defend score
squad_df['pfd_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Fin'] )
squad_df['pfd_green'] = ( squad_df['Agg'] + squad_df['Ant'] + squad_df['Bra'] + squad_df['Dec'] + squad_df['Tea'] + squad_df['Wor'] + squad_df['Sta'] )
squad_df['pfd_blue'] = ( squad_df['Fir'] + squad_df['Cmp'] + squad_df['Cnt'] + squad_df['Agi'] + squad_df['Bal'] + squad_df['Str'] )
squad_df['pfd'] =( ( ( squad_df['pfd_key'] * 5) + (squad_df['pfd_green'] * 3) + (squad_df['pfd_blue'] * 1) ) / 42)
squad_df.pfd= squad_df.pfd.round(1)
    


# calculates Pressing_forward_Support score
squad_df['pfs_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Fin'] )
squad_df['pfs_green'] = ( squad_df['Agg'] + squad_df['Ant'] + squad_df['Bra'] + squad_df['Dec'] + squad_df['Tea'] + squad_df['Wor'] + squad_df['Sta'] )
squad_df['pfs_blue'] = ( squad_df['Fir'] + squad_df['Pas'] + squad_df['Cmp'] + squad_df['Cnt'] + squad_df['OtB'] + squad_df['Agi'] + squad_df['Bal'] + squad_df['Str'] )
squad_df['pfs'] =( ( ( squad_df['pfs_key'] * 5) + (squad_df['pfs_green'] * 3) + (squad_df['pfs_blue'] * 1) ) / 44)
squad_df.pfs= squad_df.pfs.round(1)
    


# calculates Pressing_forward_Attack score
squad_df['pfa_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Fin'] )
squad_df['pfa_green'] = ( squad_df['Agg'] + squad_df['Ant'] + squad_df['Bra'] + squad_df['OtB'] + squad_df['Tea'] + squad_df['Wor'] + squad_df['Sta'] )
squad_df['pfa_blue'] = ( squad_df['Fir'] + squad_df['Cmp'] + squad_df['Cnt'] + squad_df['Dec'] + squad_df['Agi'] + squad_df['Bal'] + squad_df['Str'] )
squad_df['pfa'] =( ( ( squad_df['pfa_key'] * 5) + (squad_df['pfa_green'] * 3) + (squad_df['pfa_blue'] * 1) ) / 43)
squad_df.pfa= squad_df.pfa.round(1)
    


# calculates Target_forward_Support score
squad_df['tfs_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Fin'] )
squad_df['tfs_green'] = ( squad_df['Hea'] + squad_df['Bra'] + squad_df['Tea'] + squad_df['Bal'] + squad_df['Jum'] + squad_df['Str'] )
squad_df['tfs_blue'] = ( squad_df['Fir'] + squad_df['Agg'] + squad_df['Ant'] + squad_df['Cmp'] + squad_df['Dec'] + squad_df['OtB'] )
squad_df['tfs'] =( ( ( squad_df['tfs_key'] * 5) + (squad_df['tfs_green'] * 3) + (squad_df['tfs_blue'] * 1) ) / 39)
squad_df.tfs= squad_df.tfs.round(1)
    


# calculates Target_forward_Attack score
squad_df['tfa_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Fin'] )
squad_df['tfa_green'] = ( squad_df['Hea'] + squad_df['Bra'] + squad_df['Cmp'] + squad_df['OtB'] + squad_df['Bal'] + squad_df['Jum'] + squad_df['Str'] )
squad_df['tfa_blue'] = ( squad_df['Fir'] + squad_df['Agg'] + squad_df['Ant'] + squad_df['Dec'] + squad_df['Tea'] )
squad_df['tfa'] =( ( ( squad_df['tfa_key'] * 5) + (squad_df['tfa_green'] * 3) + (squad_df['tfa_blue'] * 1) ) / 41)
squad_df.tfa= squad_df.tfa.round(1)
    


# calculates Trequartista_Attack score
squad_df['trea_key'] = ( squad_df['Acc'] + squad_df['Pac'] + squad_df['Fin'] )
squad_df['trea_green'] = ( squad_df['Dri'] + squad_df['Fir'] + squad_df['Pas'] + squad_df['Tec'] + squad_df['Cmp'] + squad_df['Dec'] + squad_df['Fla'] + squad_df['OtB'] + squad_df['Vis'] )
squad_df['trea_blue'] = ( squad_df['Ant'] + squad_df['Agi'] + squad_df['Bal'] )
squad_df['trea'] =( ( ( squad_df['trea_key'] * 5) + (squad_df['trea_green'] * 3) + (squad_df['trea_blue'] * 1) ) / 45)
squad_df.trea= squad_df.trea.round(1)
# Out:
# C:\Users\DELL 5590\AppData\Local\Temp\ipykernel_10904\3180404178.py:212: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\DELL 5590\AppData\Local\Temp\ipykernel_10904\3180404178.py:218: PerformanceWarning:
#
# DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#
# C:\Users\DELL 5590\AppData\Local\Temp\ipykernel_10904\3180404178.py:219: PerformanceWarning:
#
# ...

# %% [markdown]
# ### Tactics Positions

# %% [markdown]
# ### There are multiple tactics i use.
# 1. Xavi inspired possession tactic.
# 2. Pep inspired positional play tactic.

# %%
pep_tactic_positions = [
    'afa',
    'ifs',
    'ifs',
    'iws',
    'mezs',
    'cms',
    'dlpd',
    'wbs',
    'bpdd',
    'cwbs',
    'ska'
]

# %%
patel_ball_tactic_positions = [
    'pfs',
    'ifs',
    'wa',
    'mezs',
    'cma',
    'dms',
    'fba',
    'bpdd',
    'iwbs',
    'sks'
]

# %%
def get_position_top_10_players(tactic_positions) -> dict:
    position_top_10_players = dict()
    for position in pep_tactic_positions:
        position_top_10_players[position] = squad_df[['Name', 'Age', 'Position', 'dna_score' , position]].sort_values(by=[position, 'dna_score'], ascending=False).head(10)

    return position_top_10_players

# %%
def plot_players_position(position_dict: dict):
    for pos_name, data in position_dict.items():
        fig = px.bar(position_dict[pos_name], x='Name', y=[f"{pos_name}", 'dna_score'], height=500, text_auto=True, title=f"Position: {pos_name}", barmode="group")
        fig.show()

# %%
pep_top_10_players_by_positions =  get_position_top_10_players(pep_tactic_positions)
plot_players_position(pep_top_10_players_by_positions)
